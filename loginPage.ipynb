# %%
from tkinter import*
import random
import time
from tkinter import ttk
from tkinter import messagebox
import mysql.connector
import colorama
import PIL
from PIL import ImageTk,Image 
import requests


def main():
    win = Tk()
    app = Login_Window(win)
    win.mainloop()

class Login_Window:
    def __init__(self, root):
        self.root = root
        self.root.title("Login")
        self.root.geometry("1550x800+0+0")
        
        self.bg = ImageTk.PhotoImage(file=r"C:\Users\Administrator\Downloads\hi.png")

        
        self.lab1_bg = Label(self.root, image=self.bg)
        self.lab1_bg.place(x=0, y=0, relwidth=1, relheight=1)


        frame1 = Frame(self.root,bg="white")
        frame1.place(x=600,y=170,width=340,height=450)


        img1 = Image.open(r"C:\Users\Administrator\Downloads\hello2.jpg")

        img1 = img1.resize((100,100),Image.ANTIALIAS)
        self.photoimage1=ImageTk.PhotoImage(img1)
        lblimg1 =Label(image=self.photoimage1,bg="white",borderwidth=0)
        lblimg1.place(x=720,y=185,width=100,height=100)


        get_str =Label(frame1,text="Get Started",font=("times new roman",20,"bold"),fg="black",bg="white")
        get_str.place(x=100,y=120)


        #label
        username = Label(frame1,text="Username",font=("times new roman",15,"bold"),fg="black",bg="white")
        username.place(x=70,y=165)

        self.textuser = Entry(frame1,font=("times new roman",15,"bold"),bg="black",fg="white")
        self.textuser.place(x=40,y=190,width=250)


        password= Label(frame1,text="Password",font=("times new roman",15,"bold"),fg="black",bg="white")
        password.place(x=70,y=225)

        self.textpass = Entry(frame1,font=("times new roman",15,"bold"),bg="black",fg="white")
        self.textpass.place(x=40,y=250,width=250)

        #icon image
        img2 = Image.open(r"C:\Users\Administrator\Downloads\hhu.jfif")
        img2 = img2.resize((25,25),Image.ANTIALIAS)
        self.photoimage2=ImageTk.PhotoImage(img2)
        lblimg2 =Label(image=self.photoimage2,bg="white",borderwidth=0)
        lblimg2.place(x=640,y=333,width=25,height=25)

        img3 = Image.open(r"C:\Users\Administrator\Downloads\OIP.jfif")
        img3 = img3.resize((25,25),Image.ANTIALIAS)
        self.photoimage3=ImageTk.PhotoImage(img3)
        lblimg3 =Label(image=self.photoimage3,bg="white",borderwidth=0)
        lblimg3.place(x=640,y=395,width=25,height=25)
  

        #loginbutton
        loginbutton = Button(frame1,command=self.login,text="login",font=("times new roman",15,"bold"),bd=3,relief=RIDGE,bg="black" ,fg="white",activebackground="black",activeforeground="white")
        loginbutton.place(x=110,y=300,width=120,height=40)

        #reg button
        regbutton = Button(frame1,command=self.reg,text="Registration",font=("times new roman",12,"bold"),borderwidth=0,relief=RIDGE,bg="white" ,fg="black",activebackground="black",activeforeground="white")
        regbutton.place(x=10,y=340,width=160)
 
        #forgetpass
        forPassbutton = Button(frame1,text="Forget password",command=self.forget_pass,font=("times new roman",12,"bold"),borderwidth=0,relief=RIDGE,bg="white" ,fg="black",activebackground="black",activeforeground="white")
        forPassbutton.place(x=25,y=370,width=160)
        
    def reg(self):
        self.new_win = Toplevel(self.root)
        self.app = Register(self.new_win)
        
        


    def login(self):
            if self.textuser.get()=="" or self.textpass=="":
                 messagebox.showerror("ERROR","all fields are required")
            elif self.textuser.get() == "ankita" and self.textpass.get() == "anki":
                 messagebox.showinfo("Welcome","successfully login")    
            else:
                conn = mysql.connector.connect(host="localhost",user="root",password="Ankita@123",database="restaurant")

                cur = conn.cursor() 
                cur.execute("select * from registration where email=%s and passwordd =%s",(self.textuser.get(),
                                                                                      self.textpass.get()
                                                                                     ))
                row = cur.fetchone()
                if row == None:
                    messagebox.showerror("error","invalid username and password")
                else:
                    open_main = messagebox.askyesno("YES NO","Access only admin")
                    if open_main>0:
                        self.new_winn = Toplevel(self.root)
                        self.appp = restaurantt(self.new_winn)
                        
                    else:
                        if not open_main:
                            return
                conn.commit() 
                conn.close()
     #--------------------------------------reset password--------------------------           
                
    def reset_password(self):
        if self.ssl_combo_ne.get()=="select":
            messagebox.showerror("Error","Select the security question",parent=self.root2)
        elif self.ssa_entry_ne.get() =="":
            messagebox.showerror("error","Please enter the answer",parent=self.root2)
        elif self.new_pass_entry.get() =="":
            messagebox.showerror("error","Please enter the password",parent=self.root2)
        else:
            conn = mysql.connector.connect(host="localhost",user="root",password="Ankita@123",database="restaurant")
            cur = conn.cursor() 
            query=("select * from registration where email=%s and security_qu=%s and security_a=%s")
            value=(self.textuser.get(),self.ssl_combo_ne.get(),self.ssa_entry_ne.get(),)
            cur.execute(query,value)
            row = cur.fetchone()
            if row==None:
                messagebox.showerror("error","wrong answer",parent=self.root2)
            else:
                queryy = ("update registration set passwordd=%s where email=%s")
                valuee = (self.new_pass_entry.get(),self.textuser.get())
                cur.execute(queryy,valuee)
                
                conn.commit()
                conn.close()
                messagebox.showinfo("info","your password has been reset",parent=self.root2)
                self.root2.destroy()
            
            
    #-----------------------------------------forget password-------------------------------------            
    def forget_pass(self):
        
        
        if self.textuser.get()=="":
            messagebox.showerror("Error","Please enter the email address to reset password")
        else:
            conn = mysql.connector.connect(host="localhost",user="root",password="",database="restaurant")
            cur = conn.cursor() 
            query =("select * from registration where email=%s")
            value = (self.textuser.get(),)
            cur.execute(query,value)
            row = cur.fetchone()
            #print(row)
            
            if row==None:
                messagebox.showerror("ERROR","Please enter the valid user name")
            else:
                conn.close()
                self.root2 = Toplevel()
                self.root2.title("Forget Password")
                self.root2.geometry("340x450+610+170")
                
                l = Label(self.root2,text="Forget Password",font=("times new roman",20,"bold"),fg="white",bg="black")
                l.place(x=0,y=10,relwidth=1)
                
                ssl = Label(self.root2,text="Select Security Questions",font=("times new roman",17,"bold"),fg ="black",bg = "white")
                ssl.place(x=50,y=80)

                self.ssl_combo_ne = ttk.Combobox(self.root2 ,font=("times new roman",15,"bold"),state="readonly")
                self.ssl_combo_ne["values"]=("select","your birth place","your favourite dish","your pet name")
                self.ssl_combo_ne.place(x=50,y=110,width=250)
                self.ssl_combo_ne.current(0)

                ssa = Label(self.root2,text="Security Answer",font=("times new roman",17,"bold"),fg ="black",bg = "white")
                ssa.place(x=50,y=150)

                self.ssa_entry_ne = ttk.Entry(self.root2,font=("times new roman",15,"bold"))
                self.ssa_entry_ne.place(x=50,y=180,width=250)
                
                
                new_pass = Label(self.root2,text="New Password",font=("times new roman",17,"bold"),fg ="black",bg = "white")
                new_pass.place(x=50,y=220)

                self.new_pass_entry = ttk.Entry(self.root2,font=("times new roman",15,"bold"))
                self.new_pass_entry.place(x=50,y=250,width=250)
                
                btn = Button(self.root2,text = "Reset Password",command=self.reset_password,font=("times new roman",15,"bold"),fg ="white",bg="green")
                btn.place(x=100,y = 290)
                
                
                

            
            
                        
                      
                    
                    
                    
                    
                    
                    
                    
class Register:
    def __init__(self,root):
        self.root = root
        self.root.title("Register")
        self.root.geometry("1550x800+0+0")

#---------------------variables-------------------
        self.var_fname = StringVar()
        self.var_lname = StringVar()
        self.var_contact = StringVar()
        self.var_email= StringVar()
        self.var_security = StringVar()
        self.var_securityA = StringVar()
        self.var_PASS = StringVar()
        self.var_confpass= StringVar()
        



#-----------------bg color----------------------
        root.configure(bg="lightgreen")


#---------------- main frame-----------------
        frame = Frame(self.root,bg="white")
        frame.place(x=350,y=100,width=800,height=550)

#----------------label-------------------------
        reglab = Label(frame,text="REGESTER HERE",font=("times new roman",20,"bold"),fg ="black",bg = "white")
        reglab.place(x=270,y=20)

#-----------------labek and entry field-----------------------
        fname = Label(frame,text="First Name",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        fname.place(x=100,y=70)

        self.fname_entry = ttk.Entry(frame,textvariable=self.var_fname,font=("times new roman",15,"bold"))
        self.fname_entry.place(x=100,y=100,width=250)

        lname = Label(frame,text="Last Name",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        lname.place(x=500,y=70)
         
        self.lname_entry = ttk.Entry(frame,textvariable=self.var_lname,font=("times new roman",15,"bold"))
        self.lname_entry.place(x=500,y=100,width=250)

        contact = Label(frame,text="Contact",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        contact.place(x=100,y=150)
        
        self.contact_entry = ttk.Entry(frame,textvariable=self.var_contact,font=("times new roman",15,"bold"))
        self.contact_entry.place(x=100,y=180,width=250)

        email = Label(frame,text="Email",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        email.place(x=500,y=150)
   
        self.email_entry = ttk.Entry(frame,textvariable=self.var_email,font=("times new roman",15,"bold"))
        self.email_entry.place(x=500,y=180,width=250)

        ssl = Label(frame,text="Select Security Questions",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        ssl.place(x=100,y=230)

        self.ssl_combo = ttk.Combobox(frame,textvariable=self.var_security,font=("times new roman",15,"bold"),state="readonly")
        self.ssl_combo["values"]=("select","your birth place","your favourite dish","your pet name")
        self.ssl_combo.place(x=100,y=260,width=250)
        self.ssl_combo.current(0)

        ssa = Label(frame,text="Security Answer",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        ssa.place(x=500,y=230)

        self.ssa_entry = ttk.Entry(frame,textvariable=self.var_securityA,font=("times new roman",15,"bold"))
        self.ssa_entry.place(x=500,y=260,width=250)

        password= Label(frame,text="Password",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        password.place(x=100,y=310)

        self.pass_entry = ttk.Entry(frame,textvariable=self.var_PASS,font=("times new roman",15,"bold"))
        self.pass_entry.place(x=100,y=340,width=250)

        Cpassword= Label(frame,text="Confirm Password",font=("times new roman",17,"bold"),fg ="black",bg = "white")
        Cpassword.place(x=500,y=310)

        self.Cpass_entry = ttk.Entry(frame,textvariable=self.var_confpass,font=("times new roman",15,"bold"))
        self.Cpass_entry.place(x=500,y=340,width=250)


        #---------------------chechk button------------------------------------
        self.check_var=IntVar()
        self.checkbtn = Checkbutton(frame,variable=self.check_var,text="I agree all terms and conditions",font=("times new roman",15,"bold"),bg="white",onvalue=1,offvalue=0)
        self.checkbtn.place(x=100,y=390)
         
        



        #--------------------------button--------------------------------------
        imgg = Image.open(r"C:\Users\Administrator\Downloads\bi.jpeg")
        imgg = imgg.resize((200,50),Image.ANTIALIAS)
        self.photoimage = ImageTk.PhotoImage(imgg)
        but = Button(frame,command=self.register_data,image=self.photoimage,borderwidth=0,cursor="hand2",bg = "white")
        but.place(x=200,y=450,width=200)
        
        imgg1 = Image.open(r"C:\Users\Administrator\Downloads\o.png")
        imgg1 = imgg1.resize((100,50),Image.ANTIALIAS)
        self.photoimage1 = ImageTk.PhotoImage(imgg1)
        butt = Button(frame,command = self.ret,image=self.photoimage1,borderwidth=0,cursor="hand2",bg="white")
        butt.place(x=550,y=450,width=100)

    def register_data(self):
        if self.var_fname.get()=="" or self.var_lname.get()==""or self.var_confpass.get()==""or self.var_contact.get()==""or self.var_PASS.get()==""or self.var_email.get()==""or self.var_security.get()=="select" or self.var_securityA.get()=="":
            messagebox.showerror("ERROR","FILL ALL THE FIELDS")
        elif self.var_confpass.get()!=self.var_PASS.get():
            messagebox.showerror("error","password and confirm password must be same")
        elif self.check_var.get()==0:
            messagebox.showerror("error","Please agree terms and condition")
        else:
            conn = mysql.connector.connect(host="localhost",user="root",password="",database="restaurant")

            cur = conn.cursor() 
            query = ("select *from registration where email=%s ") 
            value =(self.var_email.get(),)
          
            cur.execute(query,value)
            row = cur.fetchone()
            if row != None:
                messagebox.showerror("error","User already exist")
            else:
                cur.execute("insert into registration values(%s,%s,%s,%s,%s,%s,%s)",(
                                                                                      self.var_fname.get(),
                                                                                      self.lname_entry.get(),
                                                                                      self.var_contact.get(),
                                                                                      self.var_email.get(),
                                                                                      self.var_security.get(),
                                                                                      self.var_securityA.get(),
                                                                                      self.var_PASS.get()
            
                                                                                     ))   
            conn.commit()
            conn.close()
            messagebox.showinfo("success","register successfully")
                    
    def ret(self):
        self.root.destroy()
        
        
class restaurantt:
    def __init__(self,root):
        self.root = root
        root.title("Restaurant Management System")
        root.geometry("1270x690+0+0")
        
        self.root.config(bg ="firebrick4")
        
        #------------------------------Variables------------------------------------
        self.var_roti_check = IntVar()
        self.var_dal_check  = IntVar()
        self.var_fish_check = IntVar()
        self.var_sabji_check = IntVar()
        self.var_kabab_check = IntVar()
        self.var_paneer_check = IntVar()
        self.var_chicken_check = IntVar()
        self.var_chawal_check = IntVar()
        self.var_mutton_check = IntVar()
        
        self.e_roti = StringVar()
        self.e_dal = StringVar()
        self.e_fish = StringVar()
        self.e_sabji = StringVar()
        self.e_kabab = StringVar()
        self.e_chawal = StringVar()
        self.e_chicken = StringVar()
        self.e_mutton = StringVar()
        self.e_paneer = StringVar()
        
        self.var_lassi_check    =IntVar()
        self.var_coffee_check=IntVar()
        self.var_faluda_check=IntVar()
        self.var_shikanji_check=IntVar()
        self.var_jaljeera_check=IntVar()
        self.var_roohafza_check=IntVar()
        self.var_masalaTea_check=IntVar()
        self.var_badamMilk_check=IntVar()
        self.var_coldDrinks_check=IntVar()
        
        self.e_lassi=StringVar()
        self.e_coffee=StringVar()
        self.e_faluda=StringVar()
        self.e_shikanji=StringVar()
        self.e_roohafza=StringVar()
        self.e_masalaTea=StringVar()
        self.e_badamMilk=StringVar()
        self.e_coldDrinks=StringVar()
        self.e_jaljeera=StringVar()
        
        
        self.var_oreo_check=   IntVar()
        self.var_blackforest_check=   IntVar()
        self.var_choclate_check=   IntVar()
        self.var_pinapple_check=   IntVar()
        self.var_browine_check=   IntVar()
        self.var_banana_check=   IntVar()
        self.var_vanila_check=   IntVar()
        self.var_kitkat_check=   IntVar()
        self.var_apple_check=   IntVar()
        
        self.e_kitkat=StringVar()
        self.e_apple=StringVar()
        self.e_oreo=StringVar()
        self.e_vanila=StringVar()
        self.e_blackforest=StringVar()
        self.e_choclate=StringVar()
        self.e_pinapple=StringVar()
        self.e_browine=StringVar()
        self.e_banana=StringVar()
        
        
        self.e_roti.set('0')
        self.e_dal.set('0')
        self.e_fish.set('0')
        self.e_sabji.set('0')
        self.e_kabab.set('0')
        self.e_chawal.set('0')
        self.e_chicken.set('0')
        self.e_mutton.set('0')
        self.e_paneer.set('0')
        
        self.e_lassi.set('0')
        self.e_coffee.set('0')
        self.e_faluda.set('0')
        self.e_shikanji.set('0')
        self.e_roohafza.set('0')
        self.e_masalaTea.set('0')
        self.e_badamMilk.set('0')
        self.e_coldDrinks.set('0')
        self.e_jaljeera.set('0')
        
        
        self.e_kitkat.set('0')
        self.e_apple.set('0')
        self.e_oreo.set('0')
        self.e_vanila.set('0')
        self.e_blackforest.set('0')
        self.e_choclate.set('0')
        self.e_pinapple.set('0')
        self.e_browine.set('0')
        self.e_banana.set('0')
        
        self.cost_of_food=StringVar()
        self.total_cost=StringVar()
        self.service_tax=StringVar()
        self.subtotal=StringVar()
        self.cost_of_sweet=StringVar()
        self.cost_of_drinks=StringVar()
        self.order_no=StringVar()
        self.date = StringVar()
        
        self.x = random.randint(100,100000)
        self.bill_num = 'Bill\t'+str(self.x)
        self.datee = time.strftime('%d/%m/%Y')
        
        
        
        
        
        
       #--------------------------frames------------------------------------------------
        #topframe
        self.topframe = Frame(self.root,bd=10,relief=RIDGE,bg="firebrick4")
        self.topframe.pack(side=TOP)
        
        #menuframe
        self.menuframe = Frame(self.root,bd = 10,relief=RIDGE,bg="firebrick4",pady=50)
        self.menuframe.pack(side=LEFT)
        
        #costframe
        self.costframe = Frame(self.menuframe,bd=10,relief=RIDGE,bg="firebrick4",pady=40)
        self.costframe.pack(side=BOTTOM)
        
        #foodframe
        self.foodframe = LabelFrame(self.menuframe,text="Food",font=("arial",19,"bold"),bd=10,relief=RIDGE,fg="red4")
        self.foodframe.pack(side=LEFT)
        
        #drinksframe
        self.drinksframe = LabelFrame(self.menuframe,text="BEVRAGES",font=("arial",19,"bold"),bd=10,relief=RIDGE,fg="red4")
        self.drinksframe.pack(side=LEFT)
        
        #sweetframe
        self.sweetframe = LabelFrame(self.menuframe,text="SWEETS",font=("arial",19,"bold"),bd=10,relief=RIDGE,fg="red4")
        self.sweetframe.pack(side=LEFT)
        
        #rightframe
        self.rightframe = Frame(self.root,bd=15,relief=RIDGE,pady=130,bg="red4")
        self.rightframe.pack(side=RIGHT)
        
        #calculatorframe
        self.calculatorframe = Frame(self.rightframe,bd = 1,relief=RIDGE,bg="red4")
        self.calculatorframe.pack()
        
        #reciptframe
        self.reciptframe = Frame(self.rightframe,bd=4,relief=RIDGE,bg="red4")
        self.reciptframe.pack()
        
        #button frame
        self.buttonframe = Frame(self.rightframe,bd=3,relief=RIDGE,bg="red4")
        self.buttonframe.pack()
        
        #------------------------check button food----------------------------
        
        self.roti = Checkbutton(self.foodframe,text="Roti",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_roti_check,
                                command=self.roti)
        self.roti.grid(row=0,column=0,sticky=W)
        
        self.dal = Checkbutton(self.foodframe,text="Dal",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_dal_check,
                              command=self.dal)
        self.dal.grid(row=1,column =0,sticky=W)
        
        self.fish = Checkbutton(self.foodframe,text="Fish",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_fish_check,
                               command=self.fish)
        self.fish.grid(row=2,column =0,sticky=W)
        
        self.sabji = Checkbutton(self.foodframe,text="Sabji",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_sabji_check,
                                command=self.sabji)
        self.sabji.grid(row=3,column =0,sticky=W)
        
        self.kabab = Checkbutton(self.foodframe,text="Kabab",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_kabab_check,
                                command=self.kabab)
        self.kabab.grid(row=4,column =0,sticky=W)
        
        self.paneer = Checkbutton(self.foodframe,text="Paneer",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_paneer_check,
                                 command=self.paneer)
        self.paneer.grid(row=5,column =0,sticky=W)
        
        
        self.chawal = Checkbutton(self.foodframe,text="Chawal",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_chawal_check,
                                 command=self.chawal)
        self.chawal.grid(row=6,column =0,sticky=W)
        
        self.chicken = Checkbutton(self.foodframe,text="Chicken",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_chicken_check,
                                  command=self.chicken)
        self.chicken.grid(row=7,column =0,sticky=W)
        
        self.mutton = Checkbutton(self.foodframe,text="Mutton",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_mutton_check,
                                 command=self.mutton)
        self.mutton.grid(row=8,column =0,sticky=W)
        
        
        
        
        #-------------------------entry field for food----------------------------------------
        self.text_roti = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_roti)
        self.text_roti.grid(row=0,column=1)
        
        self.text_dal = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_dal)
        self.text_dal.grid(row=1,column=1)
        
        self.text_fish = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_fish)
        self.text_fish.grid(row=2,column=1)
        
        self.text_sabji = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_sabji)
        self.text_sabji.grid(row=3,column=1)
        
        self.text_kabab = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_kabab)
        self.text_kabab.grid(row=4,column=1)
        
        self.text_paneer = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_paneer)
        self.text_paneer.grid(row=5,column=1)
        
        self.text_chawal = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_chawal)
        self.text_chawal.grid(row=6,column=1)
        
        self.text_chicken = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_chicken)
        self.text_chicken.grid(row=7,column=1)
        
        self.text_mutton = Entry(self.foodframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_mutton)
        self.text_mutton.grid(row=8,column=1)
        
        
        
        #--------------------------------drinks checkbutton-----------------------------------------------
        self.Lassi = Checkbutton(self.drinksframe,text="Lassi",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_lassi_check,
                                command=self.lassi)
        self.Lassi.grid(row=0,column =0,sticky=W)
        
        
        self.coffee = Checkbutton(self.drinksframe,text="Coffee",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_coffee_check,
                                 command=self.coffee)
        self.coffee.grid(row=1,column =0,sticky=W)
        
        
        self.faluda = Checkbutton(self.drinksframe,text="Faluda",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_faluda_check,
                                 command=self.faluda)
        self.faluda.grid(row=2,column =0,sticky=W)
        
        
        self.shikanji = Checkbutton(self.drinksframe,text="Shikanji",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_shikanji_check,
                                   command=self.shikanji)
        self.shikanji.grid(row=3,column =0,sticky=W)
        
        
        self.jaljeera = Checkbutton(self.drinksframe,text="Jaljeera",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_jaljeera_check,
                                   command=self.jaljeera)
        self.jaljeera.grid(row=4,column =0,sticky=W)
        
        
        self.roohafza = Checkbutton(self.drinksframe,text="Roohafza",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_roohafza_check,
                                   command=self.roohafza)
        self.roohafza.grid(row=5,column =0,sticky=W)
        
        
        self.masalaTea = Checkbutton(self.drinksframe,text="MasalaTea",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_masalaTea_check,
                                    command=self.masalaTea)
        self.masalaTea.grid(row=6,column =0,sticky=W)
        
        
        self.badamMilk = Checkbutton(self.drinksframe,text="BadamMilk",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_badamMilk_check,
                                    command=self.badamMilk)
        self.badamMilk.grid(row=7,column =0,sticky=W)
        
        
        self.coldDrinks = Checkbutton(self.drinksframe,text="ColdDrinks",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_coldDrinks_check,
                                     command=self.coldDrinks)
        self.coldDrinks.grid(row=8,column =0,sticky=W)
        
        
        #-------------------------------drinks entry------------------------------------------------------
        self.text_lassi = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_lassi)
        self.text_lassi.grid(row=0,column=1)
        
        self.text_coffee = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_coffee)
        self.text_coffee.grid(row=1,column=1)
        
        self.text_faluda = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_faluda)
        self.text_faluda.grid(row=2,column=1)
        
        self.text_shikanji = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_shikanji)
        self.text_shikanji.grid(row=3,column=1)
        
        self.text_roohafza = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_roohafza)
        self.text_roohafza.grid(row=5,column=1)
        
        self.text_masalaTea = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_masalaTea)
        self.text_masalaTea.grid(row=6,column=1)
        
        self.text_badamMilk = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_badamMilk)
        self.text_badamMilk.grid(row=7,column=1)
        
        self.text_coldDrinks = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_coldDrinks)
        self.text_coldDrinks.grid(row=8,column=1)
        
        self.text_jaljeera = Entry(self.drinksframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_jaljeera)
        self.text_jaljeera.grid(row=4,column=1)
        
        
        #--------------------------------sweet checkbox---------------------------------------------------------------
        self.oreo = Checkbutton(self.sweetframe,text="oreocake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_oreo_check,
                               command = self.oreo)
        self.oreo.grid(row=0,column =0,sticky=W)
        
        self.apple = Checkbutton(self.sweetframe,text="applecake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_apple_check,
                                command = self.apple)
        self.apple.grid(row=1,column =0,sticky=W)
        
        self.kitkat = Checkbutton(self.sweetframe,text="kitkatcake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_kitkat_check,
                                 command = self.kitkat)
        self.kitkat.grid(row=2,column =0,sticky=W)
        
        self.vanila = Checkbutton(self.sweetframe,text="vanilacake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_vanila_check,
                                 command = self.vanila)
        self.vanila.grid(row=3,column =0,sticky=W)
        
        self.banana = Checkbutton(self.sweetframe,text="bananacake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_banana_check,
                                 command = self.banana)
        self.banana.grid(row=4,column =0,sticky=W)
        
        self.browine = Checkbutton(self.sweetframe,text="browinecake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_browine_check,
                                  command = self.browine)
        self.browine.grid(row=5,column =0,sticky=W)
        
        self.pinapple = Checkbutton(self.sweetframe,text="pinapplecake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_pinapple_check,
                                   command = self.pinapple)
        self.pinapple.grid(row=6,column =0,sticky=W)
        
        self.choclate = Checkbutton(self.sweetframe,text="choclatecake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_choclate_check,
                                   command = self.choclate)
        self.choclate.grid(row=7,column =0,sticky=W)
        
        self.blackforest = Checkbutton(self.sweetframe,text="blackforestcake",font=("arial",18,"bold"),
                                onvalue=1,offvalue=0,variable = self.var_blackforest_check,
                                      command = self.blackforest)
        self.blackforest.grid(row=8,column =0,sticky=W)
        
        
        
        
        #-----------------------------------------sweet entry----------------------------------------------------
        self.text_oreo = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_oreo)
        self.text_oreo.grid(row=0,column=1)
        
        self.text_apple = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_apple)
        self.text_apple.grid(row=1,column=1)
        
        self.text_kitkat = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_kitkat)
        self.text_kitkat.grid(row=2,column=1)
        
        self.text_vanila = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_vanila)
        self.text_vanila.grid(row=3,column=1)
        
        self.text_banana = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_banana)
        self.text_banana.grid(row=4,column=1)
        
        self.text_browine = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_browine)
        self.text_browine.grid(row=5,column=1)
        
        self.text_pinapple = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_pinapple)
        self.text_pinapple.grid(row=6,column=1)
        
        self.text_choclate = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_choclate)
        self.text_choclate.grid(row=7,column=1)
        
        self.text_blackforest = Entry(self.sweetframe,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=self.e_blackforest)
        self.text_blackforest.grid(row=8,column=1)
        
        
        #--------------------------------cost label and entry fields-----------------------------------------
        self.label_cost_of_food = Label(self.costframe,text='Cost of Food',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_cost_of_food.grid(row=0,column=0)
        
        self.text_cost_of_food =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,state ='readonly',textvariable=self.cost_of_food)
        self.text_cost_of_food.grid(row=0,column=1,padx=45)
        
        self.label_cost_of_drinks = Label(self.costframe,text='Cost of Drinks',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_cost_of_drinks.grid(row=1,column=0)
        
        self.text_cost_of_drinks =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,state ='readonly',textvariable=self.cost_of_drinks)
        self.text_cost_of_drinks.grid(row=1,column=1,padx=45)
        
        
        self.label_cost_of_sweet = Label(self.costframe,text='Cost of Sweets',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_cost_of_sweet.grid(row=2,column=0)
        
        self.text_cost_of_sweet =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,state ='readonly',textvariable=self.cost_of_sweet)
        self.text_cost_of_sweet.grid(row=2,column=1,padx=45)
        
        self.label_subtotal = Label(self.costframe,text='Subtotal',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_subtotal.grid(row=0,column=2)
        
        self.text_subtotal =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,state ='readonly',textvariable=self.subtotal)
        self.text_subtotal.grid(row=0,column=3,padx=45)
        
        self.label_service_tax = Label(self.costframe,text='Service Tax',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_service_tax.grid(row=1,column=2)
        
        self.text_service_tax =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,state ='readonly',textvariable=self.service_tax)
        self.text_service_tax.grid(row=1,column=3,padx=45)
        
        self.label_total_cost = Label(self.costframe,text='Total Cost',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_total_cost.grid(row=2,column=2)
        
        self.text_total_cost =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,state ='readonly',textvariable=self.total_cost)
        self.text_total_cost.grid(row=2,column=3,padx=45)
        
        self.label_orderno = Label(self.costframe,text='Order No',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_orderno.grid(row=3,column=0)
        
        self.text_orderno =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,textvariable=self.order_no)
        self.text_orderno.grid(row=3,column=1,padx=45)
        
        self.label_date = Label(self.costframe,text='Date',font=("arial",16,"bold"),bg ="firebrick4",fg = "white")
        self.label_date.grid(row=3,column=2)
        
        self.text_date =Entry(self.costframe,font=("arial",16,"bold"),bd=6,width=14,textvariable=self.date)
        self.text_date.grid(row=3,column=3,padx=45)
        
        
        
        #--------------------------------buttons-------------------------------------------
        self.button_total = Button(self.buttonframe,text="Total",font=('arial',14,'bold'),fg='white',bg='red4',bd=3,padx=5
                                  ,command=self.total)
        self.button_total.grid(row=0,column=0)
        
        self.button_recpit = Button(self.buttonframe,text="Recipt",font=('arial',14,'bold'),fg='white',bg='red4',bd=3,padx=5,
                                command=self.recipt)
        self.button_recpit.grid(row=0,column=1)
        
        self.button_save = Button(self.buttonframe,text="Save",font=('arial',14,'bold'),fg='white',bg='red4',bd=3,padx=5,
                                 command = self.save)
        self.button_save.grid(row=0,column=2)
        
        self.button_send= Button(self.buttonframe,text="Send",font=('arial',14,'bold'),fg='white',bg='red4',bd=3,padx=5,
                                command= self.send)
        self.button_send.grid(row=0,column=3)
        
        self.button_reset = Button(self.buttonframe,text="Resset",font=('arial',14,'bold'),fg='white',bg='red4',bd=3,padx=5,
                                  command=self.reset)
        self.button_reset.grid(row=0,column=4)
        
        self.button_show = Button(self.buttonframe,text="Show",font=('arial',14,'bold'),fg='white',bg='red4',bd=3,padx=5,
                                 command=self.show)
        self.button_show.grid(row=0,column=5)
        
        
        #---------------------text area for recpit-----------------------
        self.text_Recipt = Text(self.reciptframe,font=('arial',12,'bold'),bd=3,width=52,height=14)
        self.text_Recipt.grid(row=0,column=0)
        
        
        #-----------------------------calculator-----------------------------
        self.calculator = Entry(self.calculatorframe,font=('arial',12,'bold'),width=42,bd=4)
        self.calculator.grid(row =0,column=0,columnspan=4)
        
        self.button_7 = Button(self.calculatorframe,text='7',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                               command=lambda:self.buttonClick('7'))
        self.button_7.grid(row=1,column=0)
        
        self.button_8 = Button(self.calculatorframe,text='8',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                              command=lambda:self.buttonClick('8'))
        self.button_8.grid(row=1,column=1)
        
        self.button_9 = Button(self.calculatorframe,text='9',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                              command=lambda:self.buttonClick('9'))
        self.button_9.grid(row=1,column=2)
        
        self.button_plus = Button(self.calculatorframe,text='+',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                                 command=lambda:self.buttonClick('+'))
        self.button_plus.grid(row=1,column=3)
        
        self.button_4 = Button(self.calculatorframe,text='4',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                              command=lambda:self.buttonClick('4'))
        self.button_4.grid(row=2,column=0)
        
        self.button_5 = Button(self.calculatorframe,text='5',font=('arial',12,'bold'),fg='red4',bg='white',bd=6,width=7,
                              command=lambda:self.buttonClick('5'))
        self.button_5.grid(row=2,column=1)
        
        self.button_6 = Button(self.calculatorframe,text='6',font=('arial',12,'bold'),fg='red4',bg='white',bd=6,width=7,
                              command=lambda:self.buttonClick('6'))
        self.button_6.grid(row=2,column=2)
        
        self.button_minus = Button(self.calculatorframe,text='-',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                                  command=lambda:self.buttonClick('-'))
        self.button_minus.grid(row=2,column=3)
        
        self.button_1 = Button(self.calculatorframe,text='1',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                              command=lambda:self.buttonClick('1'))
        self.button_1.grid(row=3,column=0)
        
        self.button_2 = Button(self.calculatorframe,text='2',font=('arial',12,'bold'),fg='red4',bg='white',bd=6,width=7,
                              command=lambda:self.buttonClick('2'))
        self.button_2.grid(row=3,column=1)
        
        self.button_3 = Button(self.calculatorframe,text='3',font=('arial',12,'bold'),fg='red4',bg='white',bd=6,width=7,
                              command=lambda:self.buttonClick('3'))
        self.button_3.grid(row=3,column=2)
        
        self.button_mul = Button(self.calculatorframe,text='*',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                                command=lambda:self.buttonClick('*'))
        self.button_mul.grid(row=3,column=3)
        
        
        self.button_ans = Button(self.calculatorframe,text='ANS',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                                command=self.answer)
        self.button_ans.grid(row=4,column=0)
        
        self.button_clear = Button(self.calculatorframe,text='clear',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                                  command=self.clear)
        self.button_clear.grid(row=4,column=1)
        
        self.button_0 = Button(self.calculatorframe,text='0',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                              command=lambda:self.buttonClick('0'))
        self.button_0.grid(row=4,column=2)
        
        self.button_div = Button(self.calculatorframe,text='/',font=('arial',12,'bold'),fg='yellow',bg='red4',bd=6,width=7,
                                command=lambda:self.buttonClick('/'))
        self.button_div.grid(row=4,column=3)
        
        
        
        
        self.label_title = Label(self.topframe,text="Restaurant Management System",font=("arial",30,"bold"),fg="yellow",bg = "red4"
                                ,width = 58,bd=9)
        self.label_title.grid(row=0,column=0)
        self.operator =''
    #-------------------------------functions----------------------------    
    def buttonClick(self,numbers):
        self.operator = self.operator+numbers
        self.calculator.delete(0,END)
        self.calculator.insert(END,self.operator)
        
    def clear(self):
        self.operator=""
        self.calculator.delete(0,END)
        
    def answer(self):
        self.result=str(eval(self.operator))
        self.calculator.delete(0,END)
        self.calculator.insert(0,self.result)
        self.operator=""
    def roti(self):
        if self.var_roti_check.get()==1:
            self.text_roti.config(state=NORMAL)
            self.text_roti.delete(0,END)
            self.text_roti.focus()
        else:
            self.text_roti.config(state=DISABLED)
            self.e_roti.set('0')
    def dal(self):
        if self.var_dal_check.get()==1:
            self.text_dal.config(state=NORMAL)
            self.text_dal.delete(0,END)
            self.text_dal.focus()
        else:
            self.text_dal.config(state=DISABLED)
            self.e_dal.set('0') 
            
    def fish(self):
        if self.var_fish_check.get()==1:
            self.text_fish.config(state=NORMAL)
            self.text_fish.delete(0,END)
            self.text_fish.focus()
        else:
            self.text_fish.config(state=DISABLED)
            self.e_fish.set('0') 
            
            
    def sabji(self):
        if self.var_sabji_check.get()==1:
            self.text_sabji.config(state=NORMAL)
            self.text_sabji.delete(0,END)
            self.text_sabji.focus()
        else:
            self.text_sabji.config(state=DISABLED)
            self.e_sabji.set('0')    
            
    def kabab(self):
        if self.var_kabab_check.get()==1:
            self.text_kabab.config(state=NORMAL)
            self.text_kabab.delete(0,END)
            self.text_kabab.focus()
        else:
            self.text_kabab.config(state=DISABLED)
            self.e_kabab.set('0') 
    def paneer(self):
        if self.var_paneer_check.get()==1:
            self.text_paneer.config(state=NORMAL)
            self.text_paneer.delete(0,END)
            self.text_paneer.focus()
        else:
            self.text_paneer.config(state=DISABLED)
            self.e_paneer.set('0')         
            
    def chicken(self):
        if self.var_chicken_check.get()==1:
            self.text_chicken.config(state=NORMAL)
            self.text_chicken.delete(0,END)
            self.text_chicken.focus()
        else:
            self.text_chicken.config(state=DISABLED)
            self.e_chicken.set('0')          
            
            
    def mutton(self):
        if self.var_mutton_check.get()==1:
            self.text_mutton.config(state=NORMAL)
            self.text_mutton.delete(0,END)
            self.text_mutton.focus()
        else:
            self.text_mutton.config(state=DISABLED)
            self.e_mutton.set('0')          
        
    def chawal(self):
        if self.var_chawal_check.get()==1:
            self.text_chawal.config(state=NORMAL)
            self.text_chawal.delete(0,END)
            self.text_chawal.focus()
        else:
            self.text_chawal.config(state=DISABLED)
            self.e_chawal.set('0')  
            
            
    def lassi(self):
        if self.var_lassi_check.get()==1:
            self.text_lassi.config(state=NORMAL)
            self.text_lassi.delete(0,END)
            self.text_lassi.focus()
        else:
            self.text_lassi.config(state=DISABLED)
            self.e_lassi.set('0')     
            
    def badamMilk(self):
        if self.var_badamMilk_check.get()==1:
            self.text_badamMilk.config(state=NORMAL)
            self.text_badamMilk.delete(0,END)
            self.text_badamMilk.focus()
        else:
            self.text_badamMilk.config(state=DISABLED)
            self.e_badamMilk.set('0')  
       
    def coldDrinks(self):
        if self.var_coldDrinks_check.get()==1:
            self.text_coldDrinks.config(state=NORMAL)
            self.text_coldDrinks.delete(0,END)
            self.text_coldDrinks.focus()
        else:
            self.text_coldDrinks.config(state=DISABLED)
            self.e_coldDrinks.set('0')  
            
            
    def masalaTea(self):
        if self.var_masalaTea_check.get()==1:
            self.text_masalaTea.config(state=NORMAL)
            self.text_masalaTea.delete(0,END)
            self.text_masalaTea.focus()
        else:
            self.text_masalaTea.config(state=DISABLED)
            self.e_masalaTea.set('0')    
     
    def roohafza(self):
        if self.var_roohafza_check.get()==1:
            self.text_roohafza.config(state=NORMAL)
            self.text_roohafza.delete(0,END)
            self.text_roohafza.focus()
        else:
            self.text_roohafza.config(state=DISABLED)
            self.e_roohafza.set('0')   
     
    def jaljeera(self):
        if self.var_jaljeera_check.get()==1:
            self.text_jaljeera.config(state=NORMAL)
            self.text_jaljeera.delete(0,END)
            self.text_jaljeera.focus()
        else:
            self.text_jaljeera.config(state=DISABLED)
            self.e_jaljeera.set('0')   
            
            
    def coffee(self):
        if self.var_coffee_check.get()==1:
            self.text_coffee.config(state=NORMAL)
            self.text_coffee.delete(0,END)
            self.text_coffee.focus()
        else:
            self.text_coffee.config(state=DISABLED)
            self.e_coffee.set('0')         
            
    def shikanji(self):
        if self.var_shikanji_check.get()==1:
            self.text_shikanji.config(state=NORMAL)
            self.text_shikanji.delete(0,END)
            self.text_shikanji.focus()
        else:
            self.text_shikanji.config(state=DISABLED)
            self.e_shikanji.set('0')  
    
    def faluda(self):
        if self.var_faluda_check.get()==1:
            self.text_faluda.config(state=NORMAL)
            self.text_faluda.delete(0,END)
            self.text_faluda.focus()
        else:
            self.text_faluda.config(state=DISABLED)
            self.e_faluda.set('0')  
            
            
            
    def oreo(self):
        if self.var_oreo_check.get()==1:
            self.text_oreo.config(state=NORMAL)
            self.text_oreo.delete(0,END)
            self.text_oreo.focus()
        else:
            self.text_oreo.config(state=DISABLED)
            self.e_oreo.set('0')  
            
            
    def blackforest(self):
        if self.var_blackforest_check.get()==1:
            self.text_blackforest.config(state=NORMAL)
            self.text_blackforest.delete(0,END)
            self.text_blackforest.focus()
        else:
            self.text_blackforest.config(state=DISABLED)
            self.e_blackforest.set('0')  
            
    def choclate(self):
        if self.var_choclate_check.get()==1:
            self.text_choclate.config(state=NORMAL)
            self.text_choclate.delete(0,END)
            self.text_choclate.focus()
        else:
            self.text_choclate.config(state=DISABLED)
            self.e_choclate.set('0')  
            
    def apple(self):
        if self.var_apple_check.get()==1:
            self.text_apple.config(state=NORMAL)
            self.text_apple.delete(0,END)
            self.text_apple.focus()
        else:
            self.text_apple.config(state=DISABLED)
            self.e_apple.set('0')  
            
            
    def kitkat(self):
        if self.var_kitkat_check.get()==1:
            self.text_kitkat.config(state=NORMAL)
            self.text_kitkat.delete(0,END)
            self.text_kitkat.focus()
        else:
            self.text_kitkat.config(state=DISABLED)
            self.e_kitkat.set('0')  
            
    def pinapple(self):
        if self.var_pinapple_check.get()==1:
            self.text_pinapple.config(state=NORMAL)
            self.text_pinapple.delete(0,END)
            self.text_pinapple.focus()
        else:
            self.text_pinapple.config(state=DISABLED)
            self.e_pinapple.set('0')  
           
    def vanila(self):
        if self.var_vanila_check.get()==1:
            self.text_vanila.config(state=NORMAL)
            self.text_vanila.delete(0,END)
            self.text_vanila.focus()
        else:
            self.text_vanila.config(state=DISABLED)
            self.e_vanila.set('0')  
            
            
    def browine(self):
        if self.var_browine_check.get()==1:
            self.text_browine.config(state=NORMAL)
            self.text_browine.delete(0,END)
            self.text_browine.focus()
        else:
            self.text_browine.config(state=DISABLED)
            self.e_browine.set('0')  
            
    def banana(self):
        if self.var_banana_check.get()==1:
            self.text_banana.config(state=NORMAL)
            self.text_banana.delete(0,END)
            self.text_banana.focus()
        else:
            self.text_banana.config(state=DISABLED)
            self.e_banana.set('0')    
            
            
    def total(self):
        if self.var_roti_check.get()or self.var_dal_check.get()or self.var_fish_check.get() or self.var_sabji_check.get()\
           or self.var_kabab_check.get()or self.var_paneer_check.get()or self.var_chicken_check.get()or self.var_chawal_check.get()\
           or self.var_mutton_check.get()or self.var_lassi_check.get()or self.var_coffee_check.get()or self.var_faluda_check.get()\
           or self.var_shikanji_check.get()or self.var_jaljeera_check.get()or self.var_roohafza_check.get()\
           or self.var_masalaTea_check.get()or self.var_badamMilk_check.get()or self.var_coldDrinks_check.get()\
           or self.var_oreo_check.get()or self.var_blackforest_check.get()or self.var_choclate_check.get()\
           or self.var_pinapple_check.get()or self.var_browine_check.get()or self.var_banana_check.get()or self.var_vanila_check.get()\
           or self.var_kitkat_check.get()or self.var_apple_check.get()!=0:
        
        
        
        
        
            self.item_roti = int(self.e_roti.get())
            self.item_dal = int(self.e_dal.get())
            self.item_fish = int(self.e_fish.get())
            self.item_kabab = int(self.e_kabab.get())
            self.item_chawal = int(self.e_chawal.get())
            self.item_mutton = int(self.e_mutton.get())
            self.item_paneer = int(self.e_paneer.get())
            self.item_chicken = int(self.e_chicken.get())
            self.item_sabji = int(self.e_sabji.get())

            self.item_lassi = int(self.e_lassi.get())
            self.item_coffee = int(self.e_coffee.get())
            self.item_faluda = int(self.e_faluda.get())
            self.item_shikanji = int(self.e_shikanji.get())
            self.item_jaljeera = int(self.e_jaljeera.get())
            self.item_roohafza = int(self.e_roohafza.get())
            self.item_masalaTea = int(self.e_masalaTea.get())
            self.item_badamMilk = int(self.e_badamMilk.get())
            self.item_coldDrinks = int(self.e_coldDrinks.get())

            self.item_oreo = int(self.e_oreo.get())
            self.item_apple = int(self.e_apple.get())
            self.item_kitkat = int(self.e_kitkat.get())
            self.item_vanila = int(self.e_vanila.get())
            self.item_banana = int(self.e_banana.get())
            self.item_browine = int(self.e_browine.get())
            self.item_pinapple = int(self.e_pinapple.get())
            self.item_choclate = int(self.e_choclate.get())
            self.item_blackforest = int(self.e_blackforest.get())


            self.pricefood =(self.item_roti*10)+(self.item_dal*60 )+(self.item_fish*100)+ (self.item_kabab*50)+(self.item_chawal*40 )+(self.item_mutton*130)+(self.item_paneer*120)+ (self.item_chicken*120)+(self.item_sabji*80)


            self.pricedrinks = (self.item_lassi*50 )+(self.item_coffee*40 )+(self.item_faluda*80 )+(self.item_shikanji*30)+(self.item_jaljeera*60)+(self.item_roohafza*90)+(self.item_masalaTea*80)+ (self.item_badamMilk*50)+(self.item_coldDrinks*20)             


            self.pricecake = (self.item_oreo*40)+(self.item_apple*500)+(self.item_kitkat*450)+ (self.item_vanila*800)+ (self.item_banana*300)+(self.item_browine*800)+ (self.item_pinapple*233)+ (self.item_choclate*550)+(self.item_blackforest*112)

            self.sub = self.pricefood+self.pricedrinks+self.pricecake                     
            self.t = self.sub+50

            self.cost_of_food.set(str(self.pricefood)+' Rs')
            self.cost_of_drinks.set(str(self.pricedrinks)+ ' Rs')
            self.cost_of_sweet.set(str(self.pricecake)+ ' Rs')
            self.subtotal.set(str(self.sub)+' Rs')
            self.service_tax.set("50 Rs")
            self.total_cost.set(str(self.t)+' Rs')
            self.order_no.set(self.bill_num)
            self.date.set(self.datee)
        else:
            messagebox.showerror("error","no item is selected")
        
     
        
    def recipt(self):
#         self.x = random.randint(100,100000)
#         self.bill_num = 'Bill\t'+str(self.x)
#         self.datee = time.strftime('%d/%m/%Y')
        if self.cost_of_food.get()!=''or self.cost_of_drinks.get()!='' or self.cost_of_sweet.get()!='':
            self.text_Recipt.delete(1.0,END)
            self.text_Recipt.insert(END,'Recepit Ref:\t\t'+self.bill_num+'\t\t'+self.datee+'\n')
            self.text_Recipt.insert(END,'******************************************************************************\n')
            self.text_Recipt.insert(END,'Items:\t\t Cost Of Items(Rs)\n')
            self.text_Recipt.insert(END,'******************************************************************************\n')

            if self.e_fish.get()!='0':
                self.text_Recipt.insert(END,f'Fish\t\t\t{int(self.e_fish.get())*100}\n\n')

            if self.e_dal.get()!='0':
                self.text_Recipt.insert(END,f'Dal\t\t\t{int(self.e_dal.get())*60}\n\n')

            if self.e_sabji.get()!='0':
                self.text_Recipt.insert(END,f'Sabji\t\t\t{int(self.e_sabji.get())*80}\n\n')

            if self.e_paneer.get()!='0':
                self.text_Recipt.insert(END,f'Paneer\t\t\t{int(self.e_paneer.get())*120}\n\n')

            if self.e_chicken.get()!='0':
                self.text_Recipt.insert(END,f'Chicken\t\t\t{int(self.e_chicken.get())*120}\n\n')

            if self.e_roti.get()!='0':
                self.text_Recipt.insert(END,f'Roti\t\t\t{int(self.e_roti.get())*10}\n\n')

            if self.e_chawal.get()!='0':
                self.text_Recipt.insert(END,f'Chawal\t\t\t{int(self.e_chawal.get())*40}\n\n')

            if self.e_mutton.get()!='0':
                self.text_Recipt.insert(END,f'Mutton\t\t\t{int(self.e_mutton.get())*130}\n\n')

            if self.e_kabab.get()!='0':
                self.text_Recipt.insert(END,f'Kabab\t\t\t{int(self.e_kabab.get())*50}\n\n')  




            if self.e_coffee.get()!='0':
                self.text_Recipt.insert(END,f'Coffee\t\t\t{int(self.e_coffee.get())*40}\n\n')

            if self.e_lassi.get()!='0':
                self.text_Recipt.insert(END,f'Lassi\t\t\t{int(self.e_lassi.get())*50}\n\n')

            if self.e_faluda.get()!='0':
                self.text_Recipt.insert(END,f'Faluda\t\t\t{int(self.e_faluda.get())*80}\n\n')

            if self.e_shikanji.get()!='0':
                self.text_Recipt.insert(END,f'Shikanji\t\t\t{int(self.e_shikanji.get())*30}\n\n')

            if self.e_jaljeera.get()!='0':
                self.text_Recipt.insert(END,f'Jaljeera\t\t\t{int(self.e_jaljeera.get())*60}\n\n')

            if self.e_roohafza.get()!='0':
                self.text_Recipt.insert(END,f'Roohafza\t\t\t{int(self.e_roohafza.get())*90}\n\n')

            if self.e_masalaTea.get()!='0':
                self.text_Recipt.insert(END,f'MasalaTea\t\t\t{int(self.e_masalaTea.get())*80}\n\n')

            if self.e_badamMilk.get()!='0':
                self.text_Recipt.insert(END,f'BadamMilk\t\t\t{int(self.e_badamMilk.get())*50}\n\n')

            if self.e_coldDrinks.get()!='0':
                self.text_Recipt.insert(END,f'ColdDrinks\t\t\t{int(self.e_coldDrinks.get())*20}\n\n')    





            if self.e_oreo.get()!='0':
                self.text_Recipt.insert(END,f'Oreo Cake\t\t\t{int(self.e_oreo.get())*40}\n\n')

            if self.e_apple.get()!='0':
                self.text_Recipt.insert(END,f'Apple Cake\t\t\t{int(self.e_apple.get())*500}\n\n')

            if self.e_kitkat.get()!='0':
                self.text_Recipt.insert(END,f'Kitkat Cake\t\t\t{int(self.e_kitkat.get())*450}\n\n')

            if self.e_vanila.get()!='0':
                self.text_Recipt.insert(END,f'Vanila\t\t\t{int(self.e_vanila.get())*800}\n\n')

            if self.e_banana.get()!='0':
                self.text_Recipt.insert(END,f'Banana Cake\t\t\t{int(self.e_banana.get())*300}\n\n')

            if self.e_browine.get()!='0':
                self.text_Recipt.insert(END,f'Browine\t\t\t{int(self.e_browine.get())*800}\n\n')

            if self.e_pinapple.get()!='0':
                self.text_Recipt.insert(END,f'Pinapple cake\t\t\t{int(self.e_pinapple.get())*233}\n\n')

            if self.e_choclate.get()!='0':
                self.text_Recipt.insert(END,f'Choclate cake\t\t\t{int(self.e_choclate.get())*550}\n\n')

            if self.e_blackforest.get()!='0':
                self.text_Recipt.insert(END,f'blackforest\t\t\t{int(self.e_blackforest.get())*112}\n\n') 

            self.text_Recipt.insert(END,'******************************************************************************\n')
            if self.cost_of_food.get() !='0 Rs':
                self.text_Recipt.insert(END,f"Cost Of Food\t\t\t{self.cost_of_food.get()}\n\n")
            if self.cost_of_drinks.get() !='0 Rs':    
                self.text_Recipt.insert(END,f"Cost Of Drinks\t\t\t{self.cost_of_drinks.get()}\n\n")
            if self.cost_of_sweet.get() !='0 Rs':    
                self.text_Recipt.insert(END,f"Cost Of Cake\t\t\t{self.cost_of_sweet.get()}\n\n")

            self.text_Recipt.insert(END,'******************************************************************************\n')

            self.text_Recipt.insert(END,f"Subtotal\t\t\t{self.subtotal.get()}\n\n")   
            self.text_Recipt.insert(END,"Service Tax\t\t\t 50 Rs \n\n")
            self.text_Recipt.insert(END,f"Total\t\t\t{self.total_cost.get()}\n\n")  
        else:
            messagebox.showerror("error","no item is selected")


    def save(self):
        if self.text_Recipt.get(1.0,END)=='\n':
            pass
        else:
                conn = mysql.connector.connect(host="localhost",user="root",password="",database="restaurant")
                cur = conn.cursor() 

                cur.execute("insert into save values(%s,%s,%s,%s,%s,%s,%s,%s)",(self.order_no.get(),
                                                              self.date.get(),
                                                              self.cost_of_food.get(),
                                                              self.cost_of_drinks.get(),
                                                              self.cost_of_sweet.get(),
                                                              self.subtotal.get(),
                                                              "50 Rs",
                                                              self.total_cost.get()
                                                               ))
                conn.commit()
                conn.close()
                messagebox.showinfo("success","register successfully")

    def msg(self):
        self.message = self.text_area.get(1.0,END)
        self.nu=self.num_entry.get()
        self.auth ='WE2ZFHfImP86RzweAUxYQD1L3Jp4tjakoKTG0CBsiXryvunVNOMrGlsXh4m5OUDqQHVECog927kWu6Jx'
        self.url = 'https://www.fast2sms.com/dev/bulk'
        self.params={ 'authorization':self.auth,
                       'message':self.message,
                       'sender-id':'FSTSMS',
                       'route':'p',
                       'language':'english'
            
                    }
        self.response=requests.get(self.url,params=self.params) 
        self.dic=self.response.json()   
        self.result=self.dic.get('return')
        if self.result==True:
            messagebox.showinfo("send successfully","send successfully")
        else:
            messagebox.showerror('error','something went wrong')
            
        self.root2.destroy()    
            
        
        
        
    def send(self):
        self.root2 = Toplevel()
        self.root2.title("SEND BILL")
        self.root2.config(bg = 'red4')
        self.root2.geometry('485x620+50+50')
        
        img1 = Image.open(r"C:\Users\Administrator\Downloads\live-chat.png")
        self.photoimage1=ImageTk.PhotoImage(img1)
        lblimg1 =Label(self.root2,image=self.photoimage1,bg ="red4",borderwidth=0)
        lblimg1.place(x=170,y=0,width=120,height=120)
        
        self.number_label = Label(self.root2,text="Mobile Number",font=('arial',18,'bold underline'),bg="red4",fg="white")
        self.number_label.place(x=160,y=120)
        
        self.num_entry = Entry(self.root2,font=('helvetica',22,'bold'),bd=3,width=24)
        self.num_entry.place(x=50,y=160)
        
        self.bill_label = Label(self.root2,text="Bill Details",font=('arial',18,'bold underline'),bg="red4",fg="white")
        self.bill_label.place(x=170,y=210)
        
        self.text_area = Text(self.root2,font=('arial',12,'bold'),bd =3,width =42,height=14)
        self.text_area.place(x=50,y=250)
        
        self.send_button = Button(self.root2,text="SEND",font=('arial',19,'bold'),bg='white',fg='red4',bd=7,relief=GROOVE,
                                 command = self.msg)
        self.send_button.place(x=180,y=530)
        
        self.text_area.delete(1.0,END)
        self.text_area.insert(END,'Recepit Ref:\t\t'+self.bill_num+'\t'+self.datee+'\n')
        self.text_area.insert(END,'***************************************************************\n')
        self.text_area.insert(END,'Items:\t\t Cost Of Items(Rs)\n')
        self.text_area.insert(END,'***************************************************************\n')        
        if self.e_fish.get()!='0':
            self.text_area.insert(END,f'Fish\t\t\t{int(self.e_fish.get())*100}\n\n')
            
        if self.e_dal.get()!='0':
            self.text_area.insert(END,f'Dal\t\t\t{int(self.e_dal.get())*60}\n\n')
            
        if self.e_sabji.get()!='0':
            self.text_area.insert(END,f'Sabji\t\t\t{int(self.e_sabji.get())*80}\n\n')
            
        if self.e_paneer.get()!='0':
            self.text_area.insert(END,f'Paneer\t\t\t{int(self.e_paneer.get())*120}\n\n')
            
        if self.e_chicken.get()!='0':
            self.text_area.insert(END,f'Chicken\t\t\t{int(self.e_chicken.get())*120}\n\n')
            
        if self.e_roti.get()!='0':
            self.text_area.insert(END,f'Roti\t\t\t{int(self.e_roti.get())*10}\n\n')
            
        if self.e_chawal.get()!='0':
            self.text_area.insert(END,f'Chawal\t\t\t{int(self.e_chawal.get())*40}\n\n')
            
        if self.e_mutton.get()!='0':
            self.text_area.insert(END,f'Mutton\t\t\t{int(self.e_mutton.get())*130}\n\n')
            
        if self.e_kabab.get()!='0':
            self.text_area.insert(END,f'Kabab\t\t\t{int(self.e_kabab.get())*50}\n\n')  
            
            
            
            
        if self.e_coffee.get()!='0':
            self.text_area.insert(END,f'Coffee\t\t\t{int(self.e_coffee.get())*40}\n\n')
            
        if self.e_lassi.get()!='0':
            self.text_area.insert(END,f'Lassi\t\t\t{int(self.e_lassi.get())*50}\n\n')
            
        if self.e_faluda.get()!='0':
            self.text_area.insert(END,f'Faluda\t\t\t{int(self.e_faluda.get())*80}\n\n')
            
        if self.e_shikanji.get()!='0':
            self.text_area.insert(END,f'Shikanji\t\t\t{int(self.e_shikanji.get())*30}\n\n')
            
        if self.e_jaljeera.get()!='0':
            self.text_area.insert(END,f'Jaljeera\t\t\t{int(self.e_jaljeera.get())*60}\n\n')
            
        if self.e_roohafza.get()!='0':
            self.text_area.insert(END,f'Roohafza\t\t\t{int(self.e_roohafza.get())*90}\n\n')
            
        if self.e_masalaTea.get()!='0':
            self.text_area.insert(END,f'MasalaTea\t\t\t{int(self.e_masalaTea.get())*80}\n\n')
            
        if self.e_badamMilk.get()!='0':
            self.text_area.insert(END,f'BadamMilk\t\t\t{int(self.e_badamMilk.get())*50}\n\n')
            
        if self.e_coldDrinks.get()!='0':
            self.text_area.insert(END,f'ColdDrinks\t\t\t{int(self.e_coldDrinks.get())*20}\n\n')    
            
            
            
            
        
        if self.e_oreo.get()!='0':
            self.text_area.insert(END,f'Oreo Cake\t\t\t{int(self.e_oreo.get())*40}\n\n')
            
        if self.e_apple.get()!='0':
            self.text_area.insert(END,f'Apple Cake\t\t\t{int(self.e_apple.get())*500}\n\n')
            
        if self.e_kitkat.get()!='0':
            self.text_area.insert(END,f'Kitkat Cake\t\t\t{int(self.e_kitkat.get())*450}\n\n')
            
        if self.e_vanila.get()!='0':
            self.text_area.insert(END,f'Vanila\t\t\t{int(self.e_vanila.get())*800}\n\n')
            
        if self.e_banana.get()!='0':
            self.text_area.insert(END,f'Banana Cake\t\t\t{int(self.e_banana.get())*300}\n\n')
            
        if self.e_browine.get()!='0':
            self.text_area.insert(END,f'Browine\t\t\t{int(self.e_browine.get())*800}\n\n')
            
        if self.e_pinapple.get()!='0':
            self.text_area.insert(END,f'Pinapple cake\t\t\t{int(self.e_pinapple.get())*233}\n\n')
            
        if self.e_choclate.get()!='0':
            self.text_area.insert(END,f'Choclate cake\t\t\t{int(self.e_choclate.get())*550}\n\n')
            
        if self.e_blackforest.get()!='0':
            self.text_area.insert(END,f'blackforest\t\t\t{int(self.e_blackforest.get())*112}\n\n') 
        self.text_area.insert(END,'***************************************************************\n')    
        if self.cost_of_food.get() !='0 Rs':
            self.text_area.insert(END,f"Cost Of Food\t\t\t{self.cost_of_food.get()}\n\n")
        if self.cost_of_drinks.get() !='0 Rs':    
            self.text_area.insert(END,f"Cost Of Drinks\t\t\t{self.cost_of_drinks.get()}\n\n")
        if self.cost_of_sweet.get() !='0 Rs':    
            self.text_area.insert(END,f"Cost Of Cake\t\t\t{self.cost_of_sweet.get()}\n\n")
            
        self.text_area.insert(END,'***************************************************************\n')    
        self.text_area.insert(END,f"Subtotal\t\t\t{self.subtotal.get()}\n\n")   
        self.text_area.insert(END,"Service Tax\t\t\t 50 Rs \n\n")
        self.text_area.insert(END,f"Total\t\t\t{self.total_cost.get()}\n\n") 
        
        
        
#          self.root2.mainloop()
    def reset(self):
        self.text_Recipt.delete(1.0,END)
        
        self.e_roti.set('0')
        self.e_dal.set('0')
        self.e_fish.set('0')
        self.e_sabji.set('0')
        self.e_kabab.set('0')
        self.e_chawal.set('0')
        self.e_chicken.set('0')
        self.e_mutton.set('0')
        self.e_paneer.set('0')
        
        self.e_lassi.set('0')
        self.e_coffee.set('0')
        self.e_faluda.set('0')
        self.e_shikanji.set('0')
        self.e_roohafza.set('0')
        self.e_masalaTea.set('0')
        self.e_badamMilk.set('0')
        self.e_coldDrinks.set('0')
        self.e_jaljeera.set('0')
        
        
        self.e_kitkat.set('0')
        self.e_apple.set('0')
        self.e_oreo.set('0')
        self.e_vanila.set('0')
        self.e_blackforest.set('0')
        self.e_choclate.set('0')
        self.e_pinapple.set('0')
        self.e_browine.set('0')
        self.e_banana.set('0')
        
        self.text_roti.config(state=DISABLED)
        
        self.text_banana.config(state=DISABLED)
        self.text_browine.config(state=DISABLED)
        self.text_vanila.config(state=DISABLED)
        self.text_pinapple.config(state=DISABLED)
        self.text_kitkat.config(state=DISABLED)
        self.text_apple.config(state=DISABLED)
        self.text_choclate.config(state=DISABLED)
        self.text_oreo.config(state=DISABLED)
        self.text_blackforest.config(state=DISABLED)
        
        self.text_faluda.config(state=DISABLED)
        self.text_shikanji.config(state=DISABLED)
        self.text_coffee.config(state=DISABLED)
        self.text_jaljeera.config(state=DISABLED)
        self.text_roohafza.config(state=DISABLED)
        self.text_masalaTea.config(state=DISABLED)
        self.text_coldDrinks.config(state=DISABLED)
        self.text_badamMilk.config(state=DISABLED)
        self.text_lassi.config(state=DISABLED)
        
        self.text_roti.config(state=DISABLED)
        self.text_chawal.config(state=DISABLED)
        self.text_paneer.config(state=DISABLED)
        self.text_mutton.config(state=DISABLED)
        self.text_chicken.config(state=DISABLED)
        self.text_paneer.config(state=DISABLED)
        self.text_kabab.config(state=DISABLED)
        self.text_sabji.config(state=DISABLED)
        self.text_fish.config(state=DISABLED)
        self.text_dal.config(state=DISABLED)
        
        self.var_roti_check.set(0)
        self.var_dal_check.set(0)
        self.var_fish_check.set(0)
        self.var_sabji_check.set(0)
        self.var_kabab_check.set(0)
        self.var_paneer_check .set(0)
        self.var_chicken_check.set(0)
        self.var_chawal_check.set(0)
        self.var_mutton_check.set(0)
        self.var_oreo_check.set(0)
        self.var_blackforest_check.set(0)
        self.var_choclate_check.set(0)
        self.var_pinapple_check.set(0)
        self.var_browine_check.set(0)
        self.var_banana_check.set(0)
        self.var_vanila_check.set(0)
        self.var_kitkat_check.set(0)
        self.var_apple_check.set(0)
        self.var_lassi_check.set(0)
        self.var_coffee_check.set(0)
        self.var_faluda_check.set(0)
        self.var_shikanji_check.set(0)
        self.var_jaljeera_check.set(0)
        self.var_roohafza_check.set(0)
        self.var_masalaTea_check.set(0)
        self.var_badamMilk_check.set(0)
        self.var_coldDrinks_check.set(0)
        
        self.cost_of_food.set('')
        self.total_cost.set('')
        self.service_tax.set('')
        self.subtotal.set('')
        self.cost_of_sweet.set('')
        self.cost_of_drinks.set('')
        self.order_no.set('')
        self.date.set('')
        
        
    def show(self):
        self.root3 = Toplevel()
        self.root3.title("Database")
        self.root3.config(bg = 'red4')
        self.root3.geometry("1270x690+0+0") 
        self.style = ttk.Style()
        self.style.configure("Treeview",
                    foreground="black",
                    rowheight=40,
                    fieldbackground="white"
                    )
        self.style.map('Treeview',
              background=[('selected', 'lightblue')])
        self.my_tree = ttk.Treeview(self.root3)
        self.my_tree['columns'] = ("Order_no", "Date", "Cost of Food", "Cost of Drinks", "Cost of Sweets", "SubTotal", "Service Tax", "Total")
        
        self.horizontal_bar = ttk.Scrollbar(self.root3, orient="horizontal")
        self.horizontal_bar.configure(command=self.my_tree.xview)
        self.my_tree.configure(xscrollcommand=self.horizontal_bar.set)
        self.horizontal_bar.pack(fill=X, side=BOTTOM)

        self.vertical_bar = ttk.Scrollbar(self.root3, orient="vertical")
        self.vertical_bar.configure(command=self.my_tree.yview)
        self.my_tree.configure(yscrollcommand=self.vertical_bar.set)
        self.vertical_bar.pack(fill=Y, side=RIGHT)
        
        
        self.my_tree.column("#0", width=0, minwidth=0)
        self.my_tree.column("Order_no", anchor=CENTER, width=140, minwidth=25)
        self.my_tree.column("Date", anchor=CENTER, width=100, minwidth=25)
        self.my_tree.column("Cost of Food", anchor=CENTER, width=120, minwidth=25)
        self.my_tree.column("Cost of Drinks", anchor=CENTER, width=140, minwidth=25)
        self.my_tree.column("Cost of Sweets", anchor=CENTER, width=120, minwidth=25)
        self.my_tree.column("SubTotal", anchor=CENTER, width=120, minwidth=25)
        self.my_tree.column("Service Tax", anchor=CENTER, width=180, minwidth=25)
        self.my_tree.column("Total", anchor=CENTER, width=120, minwidth=25)
        
        
        self.my_tree.heading("Order_no", text="Order No", anchor=CENTER)
        self.my_tree.heading("Date", text="Date", anchor=CENTER)
        self.my_tree.heading("Cost of Food", text="Cost of Food", anchor=CENTER)
        self.my_tree.heading("Cost of Drinks", text="Cost of Drinks", anchor=CENTER)
        self.my_tree.heading("Cost of Sweets", text="Cost of Sweets", anchor=CENTER)
        self.my_tree.heading("SubTotal", text="Subtotal", anchor=CENTER)
        self.my_tree.heading("Service Tax", text="Service Tax", anchor=CENTER)
        self.my_tree.heading("Total", text="Total", anchor=CENTER)
        
        self.my_tree.pack()
        
        connectn = mysql.connector.connect(host="localhost",user="root",password="",database='restaurant')
        cursor = connectn.cursor()
        
        self.my_tree.delete(*self.my_tree.get_children())
        cursor.execute("SELECT * FROM SAVE")
        self.fetch = cursor.fetchall()
        for data in self.fetch:
            self.my_tree.insert('', 'end', values=(data))
        
        connectn.commit()
        connectn.close()
        
        self.root3.mainloop()        




if __name__ == "__main__":
    main()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14556\2299359577.py:37: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img1 = img1.resize((100,100),Image.ANTIALIAS)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14556\2299359577.py:63: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img2 = img2.resize((25,25),Image.ANTIALIAS)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14556\2299359577.py:69: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img3 = img3.resize((25,25),Image.ANTIALIAS)
